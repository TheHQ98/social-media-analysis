# %%
import json
from collections import defaultdict

with open('aus_cost_of_living_random_keywords.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

city_sentiment = defaultdict(lambda: {'positive': 0, 'neutral': 0, 'negative': 0})


cost_keywords = {'cost', 'rent', 'price', 'grocery', 'transport', 'bill', 'living', 'wage', 'income', 'expensive', 'afford'}


cost_posts = []

for post in data:
    tags = post.get('data', {}).get('tags', []) + post.get('keywords', [])
    cities = [tag.lower() for tag in tags if tag.lower() in {"melbourne", "sydney", "brisbane", "adelaide", "perth", "hobart", "darwin", "canberra"}]

    sentiment = post.get('sentimentLabel', 'neutral').lower()
    for city in cities:
        city_sentiment[city][sentiment] += 1

    content = post.get('data', {}).get('content', '').lower()
    if any(keyword in content for keyword in cost_keywords):
        cost_posts.append(post)

city_ranking = []
for city, stats in city_sentiment.items():
    total = sum(stats.values())
    positive_ratio = stats['positive'] / total if total > 0 else 0
    city_ranking.append((city, positive_ratio))

city_ranking = sorted(city_ranking, key=lambda x: -x[1])

selected_posts = sorted(
    [p for p in cost_posts if 'melbourne' in p.get('keywords', []) or 'brisbane' in p.get('keywords', [])],
    key=lambda x: (-abs(x.get('sentiment', 0)), 
    (x.get('favouritesCount', 0) + x.get('reblogsCount', 0))))[:5]

print("sentiment rank：")
for idx, (city, score) in enumerate(city_ranking, 1):
    print(f"{idx}. {city.capitalize()}: {score:.1%} positive")

print("\ntop5 posts：")
for idx, post in enumerate(selected_posts, 1):
    print(f"\n{idx}. [city: {post['keywords'][0].capitalize()}]")
    print(f"   sentiment label: {post['sentimentLabel']} ({post['sentiment']})")
    print(f"   content: {post['data']['content'][:150]}...")
    print(f"   url: {post['data']['url']}")
# Out:
# sentiment rank：
# 1. Melbourne: 29.7% positive
# 2. Perth: 27.9% positive
# 3. Brisbane: 27.9% positive
# 4. Canberra: 24.6% positive
# 5. Darwin: 21.5% positive
# 6. Adelaide: 20.3% positive
# 7. Sydney: 15.8% positive
# 8. Hobart: 11.0% positive
#
# top5 posts：
#
# 1. [city: Melbourne]
#    sentiment label: positive (0.836)
#    content: <p>Something a lot of <a href="https://aus.social/tags/melbourne" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>melbourne</sp...
#    url: https://aus.social/@joannaholman/114386272508875163
#
# 2. [city: Queensland]
#    sentiment label: positive (0.712)
#    content: <p>Day 22 cont 🚜🌾 🤼 🏡🏘️🏠🏠🏠</p><p>“Traditionally, <a href="https://ioc.exchange/tags/Queensland" class="mention hashtag" rel="nofollow noopener" target...
#    url: https://ioc.exchange/@peterrenshaw/114368240128545286
#
# 3. [city: Neighbourhoods]
#    sentiment label: positive (0.619)
#    content: <p>In case you're confused about why there's such strident opposition against the Allan government's plan for more housing density around major activi...
#    url: https://gts.sadauskas.id.au/@aj/statuses/01JSGJX7QVEFWWY8ECDS88G10A
#
# 4. [city: Melbourne]
#    sentiment label: neutral (-0.301)
#    content: <p>I knew all of these, but the Night Owl name for 6pm-3am travel for the cost of a 2-hour fare is new. That pricing has been in place for 30+ years, ...
#    url: https://mastodon.social/@danielbowen/114386295953865521
#
# 5. [city: Burlesque]
#    sentiment label: neutral (0.226)
#    content: <p>If you fancy a gender bending burlesque show, highly recommend Club Kabarett, currently in <a href="https://aus.social/tags/melbourne" class="menti...
#    url: https://aus.social/@MrAndrewD/114384808860612973

# %%
import json
from collections import defaultdict

with open('aus_cost_of_living_random_keywords.json', 'r', encoding='utf-8') as f:
    data = json.load(f)


city_list = {"melbourne", "sydney", "brisbane", "adelaide", "perth", "hobart", "darwin", "canberra"}

city_sentiment = defaultdict(lambda: {'positive': 0, 'neutral': 0, 'negative': 0})
cost_keywords = {
    'cost', 'costs', 'price', 'prices', 'expensive', 'afford', 'affordable', 'cheap', 'cheaper',
    'living', 'living cost', 'living costs', 'cost of living', 'standard of living',

    'rent', 'rents', 'rental', 'renting', 'lease', 'leased',

    'grocery', 'groceries', 'supermarket', 'supermarkets', 'shopping', 'food cost', 'food prices',

    'transport', 'transportation', 'public transport', 'train fare', 'bus fare', 'uber', 'taxi', 'commute', 'commuting',

    'bill', 'bills', 'electricity bill', 'water bill', 'internet bill', 'gas bill', 'utilities', 'utility bill', 'phone bill',

    'income', 'wage', 'wages', 'salary', 'salaries', 'pay', 'payment',

    'job', 'jobs', 'unemployment', 'employment', 'underemployment',

    'mortgage', 'home loan', 'interest rate', 'housing', 'house price', 'real estate', 'property', 'housing market',

    'inflation', 'recession', 'economy', 'economic', 'financial', 'finance', 'crisis',

    'insurance', 'health insurance', 'car insurance', 'life insurance',

    'childcare', 'daycare', 'school fees', 'education cost', 'university fees', 'student debt',

    'healthcare', 'medical cost', 'hospital bill', 'doctor fee',

    'minimum wage', 'living wage', 'pay rise', 'salary increase', 'salary cut',

    'saving', 'savings', 'saving money', 'expense', 'expenses', 'spending',

    'cost crisis', 'housing crisis', 'cost pressure', 'affordability crisis'
}

city_cost_posts = defaultdict(list)

for post in data:
    tags = post.get('data', {}).get('tags', []) + post.get('keywords', [])
    tags = [tag.lower() for tag in tags]

    cities = [tag for tag in tags if tag in city_list]
    sentiment = post.get('sentimentLabel', 'neutral').lower()
    content = post.get('data', {}).get('content', '').lower()

    if any(keyword in content for keyword in cost_keywords):
        for city in cities:
            city_cost_posts[city].append(post)

    for city in cities:
        city_sentiment[city][sentiment] += 1

city_ranking = []
for city, stats in city_sentiment.items():
    total = sum(stats.values())
    positive_ratio = stats['positive'] / total if total > 0 else 0
    city_ranking.append((city, positive_ratio))

city_ranking = sorted(city_ranking, key=lambda x: -x[1])

city_selected_posts = {}
for city, posts in city_cost_posts.items():
    top_posts = sorted(
        posts,
        key=lambda x: (-abs(x.get('sentiment', 0)), 
                       -(x.get('favouritesCount', 0) + x.get('reblogsCount', 0))))[:5]
    city_selected_posts[city] = top_posts

print("sentement rank：")
for idx, (city, score) in enumerate(city_ranking, 1):
    print(f"{idx}. {city.capitalize()}: {score:.1%} positive")

for city, posts in city_selected_posts.items():
    print(f"\ncity: {city.capitalize()} top5 posts：")
    for idx, post in enumerate(posts, 1):
        content = post.get('data', {}).get('content', '').strip()
        tags = post.get('data', {}).get('tags', []) + post.get('keywords', [])
        tags = [tag.lower() for tag in tags if tag]  
        print(f"\n{idx}. content：{content[:150]}...")
        print(f"    keywords：{', '.join(tags)}")
        print(f"   url: {post['data']['url']}")
# Out:
# sentement rank：
# 1. Melbourne: 29.7% positive
# 2. Perth: 27.9% positive
# 3. Brisbane: 27.9% positive
# 4. Canberra: 24.6% positive
# 5. Darwin: 21.5% positive
# 6. Adelaide: 20.3% positive
# 7. Sydney: 15.8% positive
# 8. Hobart: 11.0% positive
#
# city: Adelaide top5 posts：
#
# 1. content：<p>Very pleased to announce the next Gavin David Young lecture in philosophy will be my friend Barry Lam (UC Riverside) talking on ‘Self-versus-Self C...
#     keywords：adelaide, philosophy, philosophy, self, conflicts, gavindavidyounglectures
#    url: https://fediphilosophy.org/@anteagle/114340591319261240
#
# 2. content：<p>No wonder were in a cost of living crisis when the cost of doing business has skyrocketedhttps://grattan.edu.au/wp-content/uploads/2025/03/Orange_B...
#     keywords：adelaide, auspol, auspol, adelaide, cost, au
#    url: https://mastodon.social/@Adrien_Aloe_Fusion/114334271879805029
#
# 3. content：<p>No wonder were in a cost of living crisis when the cost of doing business has skyrocketedhttps://grattan.edu.au/wp-content/uploads/2025/03/Orange_B...
#     keywords：adelaide, auspol, auspol, adelaide, cost, au
#    url: https://mastodon.social/@Adrien_Aloe_Fusion/114334271879805029
#
# 4. content：<p>And we have ACTUAL RAIN! For the first time in almost a year of living in Hampstead Gardens <a href="https://mastodon.social/tags/Adelaide" class="...
#     keywords：adelaide, rain, weather, raining, rain, hampstead, spitting
#    url: https://mastodon.social/@CanvasesByPeter/114368600975919922
#
# 5. content：<p>The <a href="https://aus.social/tags/Adelaide" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>Adelaide</span></a> Plains, t...
#     keywords：adelaide, auspol, climatecrisis, rainfall, weather, adelaide, february
#    url: https://aus.social/@MrLee/114350149912576869
#
# city: Sydney top5 posts：
#
# 1. content：<p>Day 20 💰💰🏭🏦🛢️☢️🕍⛪️🙏🔥</p><p>“spin-off of the US-based <a href="https://ioc.exchange/tags/CPAC" class="mention hashtag" rel="nofollow noopener" targe...
#     keywords：cpac, sydney, howard, reagan, thatcher, onenation, australianchristianlobby, alanjones, givesendgo, christian, crowdfunding, neonazis, antivaxxers, climateconspiracist, farright, advanceaustralia, hedgefund, liberal, establishment, winemaking, silentmajority, howardsbattlers, hotelier, brisbane, tattersall, auspol, lnp, nationals, australia, hedgefund, thatcher, australianchristianlobby, aeba
#    url: https://ioc.exchange/@peterrenshaw/114356050945798543
#
# 2. content：<p><span class="h-card" translate="no"><a href="https://tech.lgbt/@nina_kali_nina" class="u-url mention" rel="nofollow noopener" target="_blank">@<spa...
#     keywords：tokyo, sydney, cherryblossoms2025, cherryblossoms2025, sydney, nina_kali_nina, tokyo
#    url: https://mstdn.social/@arcadiagt5/114375810571656299
#
# 3. content：<p><span class="h-card" translate="no"><a href="https://tech.lgbt/@nina_kali_nina" class="u-url mention" rel="nofollow noopener" target="_blank">@<spa...
#     keywords：tokyo, sydney, cherryblossoms2025, cherryblossoms2025, sydney, nina_kali_nina, tokyo
#    url: https://mstdn.social/@arcadiagt5/114375810571656299
#
# 4. content：<p>Day 24 cont 💰🥷🕵🏻‍♂️👻 🖨️</p><p>“Allegra Spender has denounced as “false, misleading, and offensive” a pamphlet targeting her that is being distribut...
#     keywords：sydney, electoral, commission, aec, distribution, pamphlet, auspol, wentworth, lnp, liberal, coalition, independent, labor, allegraspender, nickward, jamessternhell, savannapeake, roanneknox, motive, auspol, wentworth, sydney
#    url: https://ioc.exchange/@peterrenshaw/114380573343450945
#
# 5. content：<p>Day 24 cont 💰🥷🕵🏻‍♂️👻 🖨️</p><p>“Allegra Spender has denounced as “false, misleading, and offensive” a pamphlet targeting her that is being distribut...
#     keywords：sydney, electoral, commission, aec, distribution, pamphlet, auspol, wentworth, lnp, liberal, coalition, independent, labor, allegraspender, nickward, jamessternhell, savannapeake, roanneknox, motive, auspol, wentworth, sydney
#    url: https://ioc.exchange/@peterrenshaw/114380573343450945
#
# city: Perth top5 posts：
#
# 1. content：<p>Day 14 cont 🗣️🎙️📺 🇺🇸</p><p>“Price was appointed to lead a government efficiency unit if the <a href="https://ioc.exchange/tags/Coalition" class="me...
#     keywords：coalition, tech, techweenie, oligarch, efficiency, australians, policy, analysis, costing, ideas, bowlingclub, perth, slogans, auspol, lnp, liberal, propaganda, jacintanampijinpaprice, indoctrination, auspol, minister, efficiency, coalition
#    url: https://ioc.exchange/@peterrenshaw/114323798890291394
#
# 2. content：<p>Day 15 💥🚂</p><p>“As Price got into full flight, Dutton’s team tried to end the press conference.</p><p>But Price kept talking.”</p><p>“When the pre...
#     keywords：governmentwaste, coalition, indigenousaffairs, auspol, lnp, liberal, perth, leadership, peterdutton, dutton, auspol, senator, perth
#    url: https://ioc.exchange/@peterrenshaw/114326993775995650
#
# 3. content：<p>Day 15 💥🚂</p><p>“As Price got into full flight, Dutton’s team tried to end the press conference.</p><p>But Price kept talking.”</p><p>“When the pre...
#     keywords：governmentwaste, coalition, indigenousaffairs, auspol, lnp, liberal, perth, leadership, peterdutton, dutton, auspol, senator, perth
#    url: https://ioc.exchange/@peterrenshaw/114326993775995650
#
# 4. content：<p>Our next branch meeting is coming up! Non-members welcome.</p><p><a href="https://aus.social/tags/rent" class="mention hashtag" rel="nofollow noope...
#     keywords：rent, union, boorloo, perth, perth, union, branch, meeting
#    url: https://aus.social/@rahuwa/114346205130157466
#
# 5. content：<p>Our next branch meeting is coming up! Non-members welcome.</p><p><a href="https://aus.social/tags/rent" class="mention hashtag" rel="nofollow noope...
#     keywords：rent, union, boorloo, perth, perth, union, branch, meeting
#    url: https://aus.social/@rahuwa/114346205130157466
#
# city: Brisbane top5 posts：
#
# 1. content：<p>A plea for funds in form of a poem, <br>from David Wakeham,<br>trying desperately not to become homeless and be separated from his cats and dog: </...
#     keywords：homelessness, mutualaid, auspol, fundraising, catsofmastodon, brisbane, dogsofmastodon, housingcrisis, poem, poetry, lyrical, solace
#    url: https://mastodon.de/@Lojie/114343130829579735
#
# 2. content：<p>Day 20 💰💰🏭🏦🛢️☢️🕍⛪️🙏🔥</p><p>“spin-off of the US-based <a href="https://ioc.exchange/tags/CPAC" class="mention hashtag" rel="nofollow noopener" targe...
#     keywords：cpac, sydney, howard, reagan, thatcher, onenation, australianchristianlobby, alanjones, givesendgo, christian, crowdfunding, neonazis, antivaxxers, climateconspiracist, farright, advanceaustralia, hedgefund, liberal, establishment, winemaking, silentmajority, howardsbattlers, hotelier, brisbane, tattersall, auspol, lnp, nationals, australia, hedgefund, thatcher, australianchristianlobby, aeba
#    url: https://ioc.exchange/@peterrenshaw/114356050945798543
#
# 3. content：<p>Just wrote a letter to my local <a href="https://aus.social/tags/brisbane" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>b...
#     keywords：brisbane, bridge, lanes, cyclists, traffic
#    url: https://aus.social/@derekbarry/114351262198423498
#
# 4. content：<p>Day 22 cont 🚜🌾 🤼 🏡🏘️🏠🏠🏠</p><p>“Traditionally, <a href="https://ioc.exchange/tags/Queensland" class="mention hashtag" rel="nofollow noopener" target...
#     keywords：queensland, canberra, power, regions, urban, arrivals, responsibility, fighting, greens, brisbane, tealmovement, independents, auspol, liberal, lnp, nationals, planning, growthcorridor, facilities, transport, basics, queensland, brisbanetimes, brisbane, canberra
#    url: https://ioc.exchange/@peterrenshaw/114368240128545286
#
# 5. content：<p>Day 22 cont 🚜🌾 🤼 🏡🏘️🏠🏠🏠</p><p>“Traditionally, <a href="https://ioc.exchange/tags/Queensland" class="mention hashtag" rel="nofollow noopener" target...
#     keywords：queensland, canberra, power, regions, urban, arrivals, responsibility, fighting, greens, brisbane, tealmovement, independents, auspol, liberal, lnp, nationals, planning, growthcorridor, facilities, transport, basics, queensland, brisbanetimes, brisbane, canberra
#    url: https://ioc.exchange/@peterrenshaw/114368240128545286
#
# city: Canberra top5 posts：
#
# 1. content：<p>Heehee, a wee bit o' fluff for our Canberrans' entertainment or irritation.</p><p><a href="https://www.canberratimes.com.au/story/8927286/who-is-a-...
#     keywords：canberra, canberrans, canberran, canberra, canberratimes
#    url: https://infosec.space/@MsDropbear42/114373355087954370
#
# 2. content：<p>Heehee, a wee bit o' fluff for our Canberrans' entertainment or irritation.</p><p><a href="https://www.canberratimes.com.au/story/8927286/who-is-a-...
#     keywords：canberra, canberrans, canberran, canberra, canberratimes
#    url: https://infosec.space/@MsDropbear42/114373355087954370
#
# 3. content：<p>Ok, this is a Senate voting guide I can get behind: </p><p><a href="https://www.donkeyvotie.org/ACT" rel="nofollow noopener" translate="no" target=...
#     keywords：ausvotes, canberra, ausvotes, canberra, senate, greens
#    url: https://aus.social/@Brett/114390256055364757
#
# 4. content：<p>Ok, this is a Senate voting guide I can get behind: </p><p><a href="https://www.donkeyvotie.org/ACT" rel="nofollow noopener" translate="no" target=...
#     keywords：ausvotes, canberra, ausvotes, canberra, senate, greens
#    url: https://aus.social/@Brett/114390256055364757
#
# 5. content：<p>Please share to get the word out. <br />Early voting started today.<br />The calibre of the candidates presenting themselves to us is important.<br...
#     keywords：canberra, candidates, canberra, voting, candidate
#    url: https://mastodon.social/@CAPADAUS/114380346109021451
#
# city: Melbourne top5 posts：
#
# 1. content：<p>Something a lot of <a href="https://aus.social/tags/melbourne" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>melbourne</sp...
#     keywords：melbourne, melbourne, beaches, beach, sandringham
#    url: https://aus.social/@joannaholman/114386272508875163
#
# 2. content：<p>Something a lot of <a href="https://aus.social/tags/melbourne" class="mention hashtag" rel="nofollow noopener" target="_blank">#<span>melbourne</sp...
#     keywords：melbourne, melbourne, beaches, beach, sandringham
#    url: https://aus.social/@joannaholman/114386272508875163
#
# 3. content：<p>In case you're confused about why there's such strident opposition against the Allan government's plan for more housing density around major activi...
#     keywords：vicpol, auspol, planning, urbanplanning, melbourne, urbanism, neighbourhoods, melbourne, suburbs, urbanplanning
#    url: https://gts.sadauskas.id.au/@aj/statuses/01JSGJX7QVEFWWY8ECDS88G10A
#
# 4. content：<p>In case you're confused about why there's such strident opposition against the Allan government's plan for more housing density around major activi...
#     keywords：vicpol, auspol, planning, urbanplanning, melbourne, urbanism, neighbourhoods, melbourne, suburbs, urbanplanning
#    url: https://gts.sadauskas.id.au/@aj/statuses/01JSGJX7QVEFWWY8ECDS88G10A
#
# 5. content：<p>The bird swooping warning at Richmond Station is back!</p><p>It took three months of complaints to get this removed last year because it was blocki...
#     keywords：melbournetrains, melbourne, transit, publictransport, melbournetrains, warning, bird, swooping
#    url: https://aus.social/@philip/114385776867391322
#
# city: Darwin top5 posts：
#
# 1. content：“…read superficially, Darwin’s ideas can indeed tip into a vision of “mindless, purposeless algorithmic” selection—a view popularized by several late-...
#     keywords：darwin, dawkins, dennet, peirce, whitehead, darwinism, darwin, teleology, organisms
#    url: https://pleroma.microblog.se/objects/3c6449b4-6f81-4c0b-9633-d79a0e783a27
#
# 2. content：“…read superficially, Darwin’s ideas can indeed tip into a vision of “mindless, purposeless algorithmic” selection—a view popularized by several late-...
#     keywords：darwin, dawkins, dennet, peirce, whitehead, darwinism, darwin, teleology, organisms
#    url: https://pleroma.microblog.se/objects/3c6449b4-6f81-4c0b-9633-d79a0e783a27
#
# 3. content：<p><span class="h-card" translate="no"><a href="https://social.treehouse.systems/@sven" class="u-url mention" rel="nofollow noopener" target="_blank">...
#     keywords：apple, 3rdpartyos, darwin, nextstep, bsd, macos, 3rdpartyos, macos, nextstep, distro
#    url: https://infosec.space/@kkarhan/114302879178416104
#
# 4. content：<p>The eastern curlews <br>have “been hammered by habitat destruction up and down the entire flyway for the past 40 years”. Sean Dooley, a senior advi...
#     keywords：birds, migratorybirds, darwin, extinctioncrisis, migratorybirds, curlews, curlew, wetlands
#    url: https://theblower.au/@Biodiversity/114298973716419763
#
# 5. content：“…many biologists, craving the prestige of physics (“physics envy”), indeed tried to reduce living phenomena to clockwork processes or gene-based inst...
#     keywords：darwin, darwinism, darwin, nature, speciation
#    url: https://pleroma.microblog.se/objects/9971cf20-786b-403d-94b5-95d80afab479
